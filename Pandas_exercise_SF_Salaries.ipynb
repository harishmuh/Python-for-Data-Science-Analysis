# %% [markdown]
# <a href="https://colab.research.google.com/github/harishmuh/Python-for-Data-Science-Analysis/blob/main/Pandas_exercise_SF_Salaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ___
#
# # **Pandas exercise - SF Salaries**
# ___
#
# Welcome to a quick exercise for you to practice your pandas skills! We will be using San Fransisco salaries dataset. The dataset is originated from [here](https://transparentcalifornia.com/salaries/san-francisco/), but we can also access it on [kaggle](). Just follow along and complete the tasks outlined in bold below. The tasks will get harder and harder as you go along.

# %% [markdown]
# **Importing libraries**

# %%
# Importing libraries
import pandas as pd

# %% [markdown]
# **Reading dataset as a dataframe called df**

# %%
# Loading dataset
url = 'https://raw.githubusercontent.com/harishmuh/Python-for-Data-Science-Analysis/refs/heads/main/datasets/Salaries.csv'
df = pd.read_csv(url)

# %% [markdown]
# **Check the head of dataframe**

# %%
# Quick review of dataset from above
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %% [markdown]
# **Check of the tail of dataframe**

# %%
# Quick review of dataset from below
df.tail()
# Out:
#             Id   EmployeeName                    JobTitle  BasePay  \
# 148649  148650  Roy I Tillery                   Custodian      0.0
# 148650  148651   Not provided                Not provided      NaN
# 148651  148652   Not provided                Not provided      NaN
# 148652  148653   Not provided                Not provided      NaN
# 148653  148654      Joe Lopez  Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148649          0.0      0.00       0.0      0.00              0.00  2014
# 148650          NaN       NaN       NaN      0.00              0.00  2014
# 148651          NaN       NaN       NaN      0.00              0.00  2014
# 148652          NaN       NaN       NaN      0.00              0.00  2014
# 148653          0.0   -618.13       0.0   -618.13           -618.13  2014
#
#         Notes         Agency  Status
# 148649    NaN  San Francisco     NaN
# 148650    NaN  San Francisco     NaN
# ...

# %% [markdown]
# **How many entries of the dataframe?**

# %%
# Data dimension # Number of (Rows, columns)
df.shape
# Out:
# (148654, 13)

# %%
# Data summary and data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %% [markdown]
# **Statistical descriptive**

# %%
# Statistical descriptive # Numeric
df.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448840    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes  \
# count  112491.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    25007.893151   74768.321972      93692.554811    2012.522643    NaN
# std     15402.215858   50517.005274      62793.533483       1.117538    NaN
# ...

# %%
# Statistical descriptive # Object
df.describe(include='object')
# Out:
#        EmployeeName          JobTitle         Agency
# count        148654            148654         148654
# unique       110811              2159              1
# top       Kevin Lee  Transit Operator  San Francisco
# freq             13              7036         148654

# %% [markdown]
# **What is the average BasePay ?**

# %%
# Average BasePay
print(df['BasePay'].mean())
# Out:
# 66325.4488404877

# %% [markdown]
# **What is the highest amount of OvertimePay in the dataset?**

# %%
# The highest Overtime Pay
print(df['OvertimePay'].max())
# Out:
# 245131.88

# %% [markdown]
# **What is the job title of  JOSEPH DRISCOLL?** *Note: Use all caps, otherwise you may get an answer that doesn't match up (there is also a lowercase Joseph Driscoll).

# %%
# Job title of JOSEPH DRISCOLL
df[df['EmployeeName'] == 'JOSEPH DRISCOLL']['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %% [markdown]
# **How much does JOSEPH DRISCOLL make (including benefits)?**

# %%
# TotalPayBenefits of JOSEPH DRISCOLL
df[df['EmployeeName'] == 'JOSEPH DRISCOLL']['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# **What is the name of highest paid person (including benefits)?**

# %%
# The highest paid person
df[df['TotalPayBenefits'] == df['TotalPayBenefits'].max()]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %% [markdown]
# **What was the average (mean) BasePay of all employees per year? (2011-2014) ?**

# %%
# Average BasePay (2011-2014)
df['BasePay'] = pd.to_numeric(df['BasePay'], errors='coerce') # Converts 'BasePay' to numeric, replacing errors with NaN
df['Year'] = pd.to_numeric(df['Year'], errors='coerce') # Converts 'Year' to numeric, replacing errors with NaN
df.groupby('Year')['BasePay'].mean()
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# **How many unique job titles are there?**

# %%
# Unique JobTitle
df['JobTitle'].nunique()
# Out:
# 2159

# %% [markdown]
# **What are the top 5 most common jobs?**

# %%
# Most common jobs
df['JobTitle'].value_counts().head(5)
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: count, dtype: int64

# %% [markdown]
# **How many people have the word Chief in their job title? (This is pretty tricky)**

# %%
# Define Function to search 'chief'
def count_chief_in_text(df, column_name):
    return df[column_name].str.lower().str.contains('chief', na=False).sum()

# %%
# Calculating the number of 'chief' in Jobtitle
count = count_chief_in_text(df, 'JobTitle')
print(f"Number of JobTitle containing 'chief': {count}")
# Out:
# Number of JobTitle containing 'chief': 627

# %% [markdown]
# # Great Job!
