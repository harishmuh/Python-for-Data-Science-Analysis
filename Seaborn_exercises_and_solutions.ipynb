# %% [markdown]
# <a href="https://colab.research.google.com/github/harishmuh/Python-for-Data-Science-Analysis/blob/main/Seaborn_exercises_and_solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ___
#
# # **Seaborn Exercises and Solutions**
# ___
#
# Time to practice your new seaborn skills! Try to recreate the plots below (don't worry about color schemes, just the plot itself).

# %% [markdown]
# **Dataset**
#
# We will use the titanic dataset for exercise. At the moment, we will just focus on the visualization of the data with seaborn

# %% [markdown]
# **Importing seaborn and required libraries**

# %%
# Importing seaborn library
import seaborn as sns

# Importing matplotlib library (supporting display)
import matplotlib.pyplot as plt
# %matplotlib inline

# Customizing with 'ggplot' style
# plt.style.use('ggplot')

# Importing warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Customizing style
sns.set_style('whitegrid')

# %%
# Loading dataset
df = sns.load_dataset('titanic')

# %%
# Quick review
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Exercises
#
# * Recreate the plots below using the titanic dataframe.
# * There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution.
# * Keep careful attention to the x and y labels for hints.
#
# *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!*

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
# Creating JoinPlot
sns.jointplot(x='fare', y='age', data=df)
plt.show()

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
# Creating displot
sns.displot(df['fare'], kde=False, bins=30, color='red')
plt.show()

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
# Creating boxplot
sns.boxplot(x='class', y='age', data=df, palette='rainbow')
plt.show()

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
# Creating swarmplot
sns.swarmplot(x='class', y='age', data=df, palette='Set2')
plt.show()

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
# Countplot
sns.countplot(x='sex', data=df, palette='Set1')
plt.show()

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
# Creating heatmap
sns.heatmap(df.corr(numeric_only=True), cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
# Creating FacetGrid
g = sns.FacetGrid(df, col='sex', row='class')
g.map(plt.hist, 'age')
plt.show()

# %% [markdown]
# **Great Job!**
