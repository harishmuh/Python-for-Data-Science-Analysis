# %% [markdown]
# <a href="https://colab.research.google.com/github/harishmuh/Python-for-Data-Science-Analysis/blob/main/Seaborn_Regression_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ___
#
# # **Regression Plots**
# ___
#
# Seaborn has many built-in capabilities for regression plots, but we will only cover the **lmplot()** function for now.
#
# **lmplot** allows you to display linear models, but it also conveniently allows you to split up those plots based off of features, as well as coloring the hue based off of features.
#
# Let's explore it

# %% [markdown]
# **Importing seaborn**

# %%
# Importing seaborn library
import seaborn as sns

# Importing matplotlib library (supporting display)
import matplotlib.pyplot as plt
# %matplotlib inline

# Customizing with 'ggplot' style
plt.style.use('ggplot')

# Importing warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Loading dataset**

# %%
# Loading dataset
df_tips = sns.load_dataset('tips') # Available on seaborn

# %%
# Quick review
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## **Implot**

# %%
# Creating implot
sns.lmplot(x='total_bill', y='tip', data=df_tips)

# Display
plt.title('Implot of total bill and tip')
plt.show()

# %%
# Modifying implot
sns.lmplot(x='total_bill', y='tip', data=df_tips, hue='sex')

# Display
plt.title('Implot of total bill and tip')
plt.show()

# %% [markdown]
# **Working with Markers**
#
# lmplot kwargs get passed through to **regplot** which is a more general form of lmplot(). regplot has a scatter_kws parameter that gets passed to plt.scatter. So we want to set the s parameter in that dictionary, which corresponds (a bit confusingly) to the squared markersize. In other words you end up passing a dictionary with the base matplotlib arguments, in this case, s for size of a scatter plot. In general, we probably won't remember this, but instead we reference the documentation: [http://matplotlib.org/api/markers_api.html](http://matplotlib.org/api/markers_api.html)

# %%
# Creating implot
sns.lmplot(x='total_bill',y='tip',data=df_tips,hue='sex',palette='coolwarm',
           markers=['o','v'],scatter_kws={'s':100})
# Display
plt.title('Implot of total bill and tip')
plt.show()

# %% [markdown]
# ## **Using a Grid**
#
# We can add more variable separation through columns and rows with the use of a grid. Just indicate this with the col or row arguments:

# %%
# Creating implot on facetgrid
sns.lmplot(x='total_bill',y='tip',data=df_tips,col='sex')

# Display
plt.show()

# %%
# Creating implot on facetgrid
sns.lmplot(x="total_bill", y="tip", row="sex", col="time",data=df_tips)
plt.show()

# %%
# Creating implot on grid
sns.lmplot(x='total_bill',y='tip', data=df_tips, col='day', hue='sex',palette='coolwarm')

plt.show()

# %% [markdown]
# ## **Aspect and Size**
#
# Seaborn figures can have their size and aspect ratio adjusted with the **size** and **aspect** parameters:

# %%
# Adjusting size (height) and aspect ratio
sns.lmplot(x='total_bill',y='tip',data=df_tips,col='day',hue='sex',palette='coolwarm',
          aspect=0.6,height=8)
plt.show()

# %% [markdown]
# **Great Job!**
